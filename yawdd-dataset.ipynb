# %%
# !curl http://skuld.cs.umass.edu/traces/mmsys/2014/user06.tar -o file.tar

# %%
# !tar -xvf file.tar
# Out:
# x user06/
# x user06/YawDD dataset.rar: Truncated tar archive detected while reading data: Unknown error
# tar: Error exit delayed from previous errors.

# %%
# !apt install unar -y
# Out:
# 'apt' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !cd dataset/user06 && unar 'YawDD dataset.rar'
# Out:
# The system cannot find the path specified.

# %%
# !mv 'dataset_zip/user06/YawDD dataset' 'YawDD dataset'

# %%
# !rm -rf dataset_zip
